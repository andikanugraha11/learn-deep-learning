# %%
import tensorflow as tf
import pandas as pd
# Out:
# c:\users\devan\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
#normalize data
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
col_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[col_to_norm] = diabetes[col_to_norm].apply(lambda x: (x-x.min())/(x.max()-x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_bucket = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70])

# %%
feat_cols = [num_preg,plasma_gluc,dias_press,tricep,insulin,bmi,diabetes_pedigree,assigned_group,age_bucket]

# %%
#Train test split
x_data = diabetes.drop('Class',axis=1)

# %%
x_data.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age Group
# 0  0.500745  0.234415   50     B
# 1  0.396423  0.116567   31     C
# 2  0.347243  0.253629   32     B
# 3  0.418778  0.038002   21     B
# 4  0.642325  0.943638   33     C

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.3,random_state=101)

# %% [markdown]
# ## input function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train, y=y_train, batch_size=10, num_epochs=1000,shuffle=True)

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\devan\AppData\Local\Temp\tmpwlkplx4o
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\devan\\AppData\\Local\\Temp\\tmpwlkplx4o', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000220B32627F0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\devan\AppData\Local\Temp\tmpwlkplx4o\model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 130.879
# INFO:tensorflow:loss = 5.100935, step = 101 (0.766 sec)
# INFO:tensorflow:global_step/sec: 148.849
# INFO:tensorflow:loss = 6.3422785, step = 201 (0.672 sec)
# INFO:tensorflow:global_step/sec: 151.105
# INFO:tensorflow:loss = 7.4239726, step = 301 (0.663 sec)
# INFO:tensorflow:global_step/sec: 145.273
# INFO:tensorflow:loss = 7.0634203, step = 401 (0.687 sec)
# INFO:tensorflow:global_step/sec: 147.639
# INFO:tensorflow:loss = 6.8325834, step = 501 (0.678 sec)
# INFO:tensorflow:global_step/sec: 126.72
# INFO:tensorflow:loss = 4.3123164, step = 601 (0.789 sec)
# INFO:tensorflow:global_step/sec: 150.649
# INFO:tensorflow:loss = 4.837417, step = 701 (0.664 sec)
# INFO:tensorflow:global_step/sec: 147.311
# INFO:tensorflow:loss = 6.2187734, step = 801 (0.678 sec)
# INFO:tensorflow:global_step/sec: 146.447
# INFO:tensorflow:loss = 4.5821753, step = 901 (0.683 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\devan\AppData\Local\Temp\tmpwlkplx4o\model.ckpt.
# INFO:tensorflow:Loss for final step: 3.6089165.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, y=y_test, batch_size=10, num_epochs=1,shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-19-16:56:42
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\devan\AppData\Local\Temp\tmpwlkplx4o\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-19-16:56:42
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7316017, accuracy_baseline = 0.64935064, auc = 0.8010288, auc_precision_recall = 0.6498043, average_loss = 0.52307665, global_step = 1000, label/mean = 0.35064936, loss = 5.034613, prediction/mean = 0.33584812

# %%
results
# Out:
# {'accuracy': 0.7316017,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.8010288,
#  'auc_precision_recall': 0.6498043,
#  'average_loss': 0.52307665,
#  'global_step': 1000,
#  'label/mean': 0.35064936,
#  'loss': 5.034613,
#  'prediction/mean': 0.33584812}

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,batch_size=10,num_epochs=1,shuffle=False)

# %%
predictions = model.predict(pred_input_func)

# %%
my_pred = list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\devan\AppData\Local\Temp\tmpwlkplx4o\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
my_pred
# Out:
# [{'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5119899], dtype=float32),
#   'logits': array([0.04796886], dtype=float32),
#   'probabilities': array([0.4880101 , 0.51198995], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61053944], dtype=float32),
#   'logits': array([0.4495802], dtype=float32),
#   'probabilities': array([0.3894606 , 0.61053944], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33517542], dtype=float32),
#   'logits': array([-0.6848691], dtype=float32),
#   'probabilities': array([0.66482455, 0.33517542], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2923543], dtype=float32),
#   'logits': array([-0.8839773], dtype=float32),
#   'probabilities': array([0.7076457 , 0.29235426], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12080889], dtype=float32),
#   'logits': array([-1.9847924], dtype=float32),
#   'probabilities': array([0.87919104, 0.12080889], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6398231], dtype=float32),
#   'logits': array([0.5745964], dtype=float32),
#   'probabilities': array([0.3601769, 0.6398231], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5833013], dtype=float32),
#   'logits': array([0.33634055], dtype=float32),
#   'probabilities': array([0.41669866, 0.5833013 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30601373], dtype=float32),
#   'logits': array([-0.81882226], dtype=float32),
#   'probabilities': array([0.6939863, 0.3060137], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19528063], dtype=float32),
#   'logits': array([-1.416056], dtype=float32),
#   'probabilities': array([0.8047194 , 0.19528061], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22299308], dtype=float32),
#   'logits': array([-1.2483085], dtype=float32),
#   'probabilities': array([0.7770069 , 0.22299306], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11148866], dtype=float32),
#   'logits': array([-2.0756245], dtype=float32),
#   'probabilities': array([0.88851136, 0.11148867], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13179506], dtype=float32),
#   'logits': array([-1.8851796], dtype=float32),
#   'probabilities': array([0.8682049 , 0.13179506], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2582743], dtype=float32),
#   'logits': array([-1.0549573], dtype=float32),
#   'probabilities': array([0.74172574, 0.25827432], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5305322], dtype=float32),
#   'logits': array([0.12228084], dtype=float32),
#   'probabilities': array([0.46946785, 0.5305322 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15337215], dtype=float32),
#   'logits': array([-1.7083938], dtype=float32),
#   'probabilities': array([0.84662783, 0.15337215], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2923413], dtype=float32),
#   'logits': array([-0.88404], dtype=float32),
#   'probabilities': array([0.70765877, 0.2923413 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30954558], dtype=float32),
#   'logits': array([-0.80224466], dtype=float32),
#   'probabilities': array([0.6904544 , 0.30954555], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10818978], dtype=float32),
#   'logits': array([-2.1093664], dtype=float32),
#   'probabilities': array([0.89181024, 0.10818979], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33032838], dtype=float32),
#   'logits': array([-0.70670027], dtype=float32),
#   'probabilities': array([0.6696716 , 0.33032835], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12334868], dtype=float32),
#   'logits': array([-1.9610941], dtype=float32),
#   'probabilities': array([0.8766513 , 0.12334869], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18127932], dtype=float32),
#   'logits': array([-1.507704], dtype=float32),
#   'probabilities': array([0.8187207 , 0.18127932], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24658927], dtype=float32),
#   'logits': array([-1.1168864], dtype=float32),
#   'probabilities': array([0.7534107 , 0.24658929], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6222164], dtype=float32),
#   'logits': array([0.49896646], dtype=float32),
#   'probabilities': array([0.3777836, 0.6222164], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18089898], dtype=float32),
#   'logits': array([-1.5102687], dtype=float32),
#   'probabilities': array([0.81910104, 0.18089898], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1474421], dtype=float32),
#   'logits': array([-1.7548056], dtype=float32),
#   'probabilities': array([0.8525579, 0.1474421], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7453581], dtype=float32),
#   'logits': array([1.0740064], dtype=float32),
#   'probabilities': array([0.25464192, 0.7453581 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14312668], dtype=float32),
#   'logits': array([-1.7895601], dtype=float32),
#   'probabilities': array([0.85687333, 0.14312668], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27524206], dtype=float32),
#   'logits': array([-0.9681869], dtype=float32),
#   'probabilities': array([0.72475797, 0.27524203], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.08779537], dtype=float32),
#   'logits': array([-2.3408556], dtype=float32),
#   'probabilities': array([0.9122046 , 0.08779537], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5504917], dtype=float32),
#   'logits': array([0.20265734], dtype=float32),
#   'probabilities': array([0.44950834, 0.55049163], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9288412], dtype=float32),
#   'logits': array([2.569024], dtype=float32),
#   'probabilities': array([0.07115877, 0.9288412 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3882328], dtype=float32),
#   'logits': array([-0.45474666], dtype=float32),
#   'probabilities': array([0.6117672, 0.3882328], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2848236], dtype=float32),
#   'logits': array([-0.9206592], dtype=float32),
#   'probabilities': array([0.7151764, 0.2848236], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5046308], dtype=float32),
#   'logits': array([0.01852381], dtype=float32),
#   'probabilities': array([0.49536917, 0.5046308 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20067309], dtype=float32),
#   'logits': array([-1.3820928], dtype=float32),
#   'probabilities': array([0.7993269 , 0.20067309], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3495544], dtype=float32),
#   'logits': array([-0.6209983], dtype=float32),
#   'probabilities': array([0.6504456 , 0.34955442], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47050762], dtype=float32),
#   'logits': array([-0.1181066], dtype=float32),
#   'probabilities': array([0.5294924 , 0.47050762], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57703394], dtype=float32),
#   'logits': array([0.31060922], dtype=float32),
#   'probabilities': array([0.42296603, 0.57703394], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7381468], dtype=float32),
#   'logits': array([1.0363587], dtype=float32),
#   'probabilities': array([0.2618532, 0.7381468], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31870604], dtype=float32),
#   'logits': array([-0.75972474], dtype=float32),
#   'probabilities': array([0.68129396, 0.31870604], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14747751], dtype=float32),
#   'logits': array([-1.754524], dtype=float32),
#   'probabilities': array([0.8525225 , 0.14747751], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51444435], dtype=float32),
#   'logits': array([0.0577935], dtype=float32),
#   'probabilities': array([0.48555565, 0.51444435], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1266412], dtype=float32),
#   'logits': array([-1.9309886], dtype=float32),
#   'probabilities': array([0.87335885, 0.12664121], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4946448], dtype=float32),
#   'logits': array([-0.02142155], dtype=float32),
#   'probabilities': array([0.5053552 , 0.49464482], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1145651], dtype=float32),
#   'logits': array([-2.0449357], dtype=float32),
#   'probabilities': array([0.88543487, 0.1145651 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10522827], dtype=float32),
#   'logits': array([-2.1404366], dtype=float32),
#   'probabilities': array([0.8947717 , 0.10522827], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5599745], dtype=float32),
#   'logits': array([0.24105859], dtype=float32),
#   'probabilities': array([0.44002548, 0.5599745 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15437001], dtype=float32),
#   'logits': array([-1.7007296], dtype=float32),
#   'probabilities': array([0.84563, 0.15437], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1590993], dtype=float32),
#   'logits': array([-1.664945], dtype=float32),
#   'probabilities': array([0.84090066, 0.1590993 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11422591], dtype=float32),
#   'logits': array([-2.0482838], dtype=float32),
#   'probabilities': array([0.8857741, 0.1142259], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15072176], dtype=float32),
#   'logits': array([-1.7289515], dtype=float32),
#   'probabilities': array([0.8492782 , 0.15072174], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20072697], dtype=float32),
#   'logits': array([-1.381757], dtype=float32),
#   'probabilities': array([0.7992731 , 0.20072696], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22246441], dtype=float32),
#   'logits': array([-1.2513622], dtype=float32),
#   'probabilities': array([0.77753556, 0.22246441], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34350955], dtype=float32),
#   'logits': array([-0.6476931], dtype=float32),
#   'probabilities': array([0.6564904 , 0.34350955], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10140233], dtype=float32),
#   'logits': array([-2.1817393], dtype=float32),
#   'probabilities': array([0.89859766, 0.10140233], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1944931], dtype=float32),
#   'logits': array([-1.4210751], dtype=float32),
#   'probabilities': array([0.80550694, 0.1944931 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17678632], dtype=float32),
#   'logits': array([-1.5382739], dtype=float32),
#   'probabilities': array([0.82321364, 0.17678632], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18185753], dtype=float32),
#   'logits': array([-1.503813], dtype=float32),
#   'probabilities': array([0.8181425 , 0.18185751], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4450149], dtype=float32),
#   'logits': array([-0.22083354], dtype=float32),
#   'probabilities': array([0.5549851, 0.4450149], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13753907], dtype=float32),
#   'logits': array([-1.8358818], dtype=float32),
#   'probabilities': array([0.8624609 , 0.13753906], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18750197], dtype=float32),
#   'logits': array([-1.4663241], dtype=float32),
#   'probabilities': array([0.812498  , 0.18750197], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5973348], dtype=float32),
#   'logits': array([0.39437246], dtype=float32),
#   'probabilities': array([0.40266517, 0.59733486], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6009998], dtype=float32),
#   'logits': array([0.40963256], dtype=float32),
#   'probabilities': array([0.39900026, 0.6009998 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47457036], dtype=float32),
#   'logits': array([-0.1018064], dtype=float32),
#   'probabilities': array([0.5254296 , 0.47457033], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.327618], dtype=float32),
#   'logits': array([-0.7189783], dtype=float32),
#   'probabilities': array([0.672382, 0.327618], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.448576], dtype=float32),
#   'logits': array([-0.2064259], dtype=float32),
#   'probabilities': array([0.55142397, 0.44857597], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15388745], dtype=float32),
#   'logits': array([-1.7044309], dtype=float32),
#   'probabilities': array([0.84611255, 0.15388744], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15828808], dtype=float32),
#   'logits': array([-1.6710212], dtype=float32),
#   'probabilities': array([0.84171194, 0.15828808], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12324699], dtype=float32),
#   'logits': array([-1.962035], dtype=float32),
#   'probabilities': array([0.87675303, 0.12324699], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10340417], dtype=float32),
#   'logits': array([-2.1599598], dtype=float32),
#   'probabilities': array([0.89659584, 0.10340418], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5923924], dtype=float32),
#   'logits': array([0.3738643], dtype=float32),
#   'probabilities': array([0.40760761, 0.5923924 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19017102], dtype=float32),
#   'logits': array([-1.4488993], dtype=float32),
#   'probabilities': array([0.809829  , 0.19017103], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.415069], dtype=float32),
#   'logits': array([-0.3430491], dtype=float32),
#   'probabilities': array([0.584931, 0.415069], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55410886], dtype=float32),
#   'logits': array([0.21728623], dtype=float32),
#   'probabilities': array([0.44589114, 0.5541088 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27832904], dtype=float32),
#   'logits': array([-0.95276535], dtype=float32),
#   'probabilities': array([0.721671  , 0.27832904], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6013432], dtype=float32),
#   'logits': array([0.41106498], dtype=float32),
#   'probabilities': array([0.3986568, 0.6013432], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10824592], dtype=float32),
#   'logits': array([-2.1087847], dtype=float32),
#   'probabilities': array([0.89175403, 0.10824592], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6163774], dtype=float32),
#   'logits': array([0.47420013], dtype=float32),
#   'probabilities': array([0.38362265, 0.6163774 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10520761], dtype=float32),
#   'logits': array([-2.140656], dtype=float32),
#   'probabilities': array([0.8947924 , 0.10520761], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5270856], dtype=float32),
#   'logits': array([0.10844851], dtype=float32),
#   'probabilities': array([0.47291443, 0.5270856 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2835611], dtype=float32),
#   'logits': array([-0.9268652], dtype=float32),
#   'probabilities': array([0.7164389 , 0.28356114], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13024297], dtype=float32),
#   'logits': array([-1.8988122], dtype=float32),
#   'probabilities': array([0.869757  , 0.13024297], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5239406], dtype=float32),
#   'logits': array([0.0958358], dtype=float32),
#   'probabilities': array([0.47605938, 0.5239406 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57027084], dtype=float32),
#   'logits': array([0.28295624], dtype=float32),
#   'probabilities': array([0.4297292 , 0.57027084], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5204977], dtype=float32),
#   'logits': array([0.08203661], dtype=float32),
#   'probabilities': array([0.47950238, 0.5204977 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13961925], dtype=float32),
#   'logits': array([-1.8184559], dtype=float32),
#   'probabilities': array([0.8603807 , 0.13961925], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35039544], dtype=float32),
#   'logits': array([-0.61730146], dtype=float32),
#   'probabilities': array([0.64960456, 0.35039544], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12325829], dtype=float32),
#   'logits': array([-1.9619304], dtype=float32),
#   'probabilities': array([0.87674177, 0.12325829], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6703778], dtype=float32),
#   'logits': array([0.70989406], dtype=float32),
#   'probabilities': array([0.32962224, 0.67037773], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7679323], dtype=float32),
#   'logits': array([1.1966721], dtype=float32),
#   'probabilities': array([0.23206778, 0.7679323 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59988517], dtype=float32),
#   'logits': array([0.4049865], dtype=float32),
#   'probabilities': array([0.4001149 , 0.59988517], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18384334], dtype=float32),
#   'logits': array([-1.4905223], dtype=float32),
#   'probabilities': array([0.8161566 , 0.18384334], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46205038], dtype=float32),
#   'logits': array([-0.1520909], dtype=float32),
#   'probabilities': array([0.5379496, 0.4620504], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3620323], dtype=float32),
#   'logits': array([-0.56655425], dtype=float32),
#   'probabilities': array([0.6379677, 0.3620323], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40611982], dtype=float32),
#   'logits': array([-0.38002932], dtype=float32),
#   'probabilities': array([0.5938802 , 0.40611982], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33438292], dtype=float32),
#   'logits': array([-0.6884278], dtype=float32),
#   'probabilities': array([0.66561705, 0.3343829 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4127056], dtype=float32),
#   'logits': array([-0.35279167], dtype=float32),
#   'probabilities': array([0.5872944, 0.4127056], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12334557], dtype=float32),
#   'logits': array([-1.9611229], dtype=float32),
#   'probabilities': array([0.87665445, 0.12334558], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5317805], dtype=float32),
#   'logits': array([0.12729347], dtype=float32),
#   'probabilities': array([0.46821955, 0.5317805 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5069001], dtype=float32),
#   'logits': array([0.02760184], dtype=float32),
#   'probabilities': array([0.4931, 0.5069], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20666564], dtype=float32),
#   'logits': array([-1.3451425], dtype=float32),
#   'probabilities': array([0.79333436, 0.20666565], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14062758], dtype=float32),
#   'logits': array([-1.8100872], dtype=float32),
#   'probabilities': array([0.8593724, 0.1406276], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1424764], dtype=float32),
#   'logits': array([-1.7948724], dtype=float32),
#   'probabilities': array([0.8575236, 0.1424764], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2379675], dtype=float32),
#   'logits': array([-1.163855], dtype=float32),
#   'probabilities': array([0.76203245, 0.23796752], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35073426], dtype=float32),
#   'logits': array([-0.61581326], dtype=float32),
#   'probabilities': array([0.6492657 , 0.35073426], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11136902], dtype=float32),
#   'logits': array([-2.0768328], dtype=float32),
#   'probabilities': array([0.888631  , 0.11136904], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31078678], dtype=float32),
#   'logits': array([-0.7964437], dtype=float32),
#   'probabilities': array([0.6892132 , 0.31078675], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20647332], dtype=float32),
#   'logits': array([-1.346316], dtype=float32),
#   'probabilities': array([0.7935267 , 0.20647332], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07701481], dtype=float32),
#   'logits': array([-2.4836154], dtype=float32),
#   'probabilities': array([0.9229852 , 0.07701481], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10796774], dtype=float32),
#   'logits': array([-2.1116698], dtype=float32),
#   'probabilities': array([0.89203227, 0.10796774], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.71076554], dtype=float32),
#   'logits': array([0.8991052], dtype=float32),
#   'probabilities': array([0.2892344, 0.7107656], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14690903], dtype=float32),
#   'logits': array([-1.7590528], dtype=float32),
#   'probabilities': array([0.85309094, 0.146909  ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10679985], dtype=float32),
#   'logits': array([-2.1238542], dtype=float32),
#   'probabilities': array([0.89320016, 0.10679985], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12318517], dtype=float32),
#   'logits': array([-1.9626071], dtype=float32),
#   'probabilities': array([0.8768148 , 0.12318517], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4638264], dtype=float32),
#   'logits': array([-0.14494777], dtype=float32),
#   'probabilities': array([0.53617364, 0.4638264 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4215388], dtype=float32),
#   'logits': array([-0.3164596], dtype=float32),
#   'probabilities': array([0.57846117, 0.42153883], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20291947], dtype=float32),
#   'logits': array([-1.3681465], dtype=float32),
#   'probabilities': array([0.7970806 , 0.20291948], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42093608], dtype=float32),
#   'logits': array([-0.318932], dtype=float32),
#   'probabilities': array([0.57906395, 0.42093608], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15499277], dtype=float32),
#   'logits': array([-1.6959667], dtype=float32),
#   'probabilities': array([0.84500724, 0.15499276], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20139098], dtype=float32),
#   'logits': array([-1.3776233], dtype=float32),
#   'probabilities': array([0.798609  , 0.20139097], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46383017], dtype=float32),
#   'logits': array([-0.14493239], dtype=float32),
#   'probabilities': array([0.53616977, 0.46383014], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4512767], dtype=float32),
#   'logits': array([-0.19551378], dtype=float32),
#   'probabilities': array([0.54872334, 0.45127666], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10863758], dtype=float32),
#   'logits': array([-2.1047337], dtype=float32),
#   'probabilities': array([0.8913624 , 0.10863758], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36004278], dtype=float32),
#   'logits': array([-0.5751784], dtype=float32),
#   'probabilities': array([0.63995725, 0.3600428 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.62257344], dtype=float32),
#   'logits': array([0.50048554], dtype=float32),
#   'probabilities': array([0.37742656, 0.62257344], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49161023], dtype=float32),
#   'logits': array([-0.0335623], dtype=float32),
#   'probabilities': array([0.5083898, 0.4916102], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34954214], dtype=float32),
#   'logits': array([-0.6210524], dtype=float32),
#   'probabilities': array([0.65045786, 0.34954214], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53770405], dtype=float32),
#   'logits': array([0.15110314], dtype=float32),
#   'probabilities': array([0.46229592, 0.53770405], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19872575], dtype=float32),
#   'logits': array([-1.3942775], dtype=float32),
#   'probabilities': array([0.80127424, 0.19872576], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15433484], dtype=float32),
#   'logits': array([-1.700999], dtype=float32),
#   'probabilities': array([0.8456652 , 0.15433484], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10877255], dtype=float32),
#   'logits': array([-2.1033406], dtype=float32),
#   'probabilities': array([0.8912274 , 0.10877255], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2297193], dtype=float32),
#   'logits': array([-1.209897], dtype=float32),
#   'probabilities': array([0.7702807 , 0.22971928], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47431758], dtype=float32),
#   'logits': array([-0.10282028], dtype=float32),
#   'probabilities': array([0.52568245, 0.47431758], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63345945], dtype=float32),
#   'logits': array([0.54708683], dtype=float32),
#   'probabilities': array([0.36654055, 0.63345945], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19687676], dtype=float32),
#   'logits': array([-1.4059302], dtype=float32),
#   'probabilities': array([0.80312324, 0.19687676], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13647257], dtype=float32),
#   'logits': array([-1.844902], dtype=float32),
#   'probabilities': array([0.8635275 , 0.13647258], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39613917], dtype=float32),
#   'logits': array([-0.4215781], dtype=float32),
#   'probabilities': array([0.6038608 , 0.39613917], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19276257], dtype=float32),
#   'logits': array([-1.4321587], dtype=float32),
#   'probabilities': array([0.80723745, 0.19276255], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11985212], dtype=float32),
#   'logits': array([-1.9938313], dtype=float32),
#   'probabilities': array([0.8801478 , 0.11985212], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15683821], dtype=float32),
#   'logits': array([-1.681944], dtype=float32),
#   'probabilities': array([0.84316176, 0.15683822], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10578345], dtype=float32),
#   'logits': array([-2.134554], dtype=float32),
#   'probabilities': array([0.89421654, 0.10578345], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37842825], dtype=float32),
#   'logits': array([-0.49622482], dtype=float32),
#   'probabilities': array([0.6215717 , 0.37842822], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7284988], dtype=float32),
#   'logits': array([0.98701966], dtype=float32),
#   'probabilities': array([0.27150112, 0.7284988 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7378426], dtype=float32),
#   'logits': array([1.0347854], dtype=float32),
#   'probabilities': array([0.2621574, 0.7378426], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5012468], dtype=float32),
#   'logits': array([0.00498712], dtype=float32),
#   'probabilities': array([0.49875325, 0.5012468 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47290057], dtype=float32),
#   'logits': array([-0.10850418], dtype=float32),
#   'probabilities': array([0.5270995 , 0.47290057], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54381406], dtype=float32),
#   'logits': array([0.17570698], dtype=float32),
#   'probabilities': array([0.4561859 , 0.54381406], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09288225], dtype=float32),
#   'logits': array([-2.2789397], dtype=float32),
#   'probabilities': array([0.9071178 , 0.09288225], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49408507], dtype=float32),
#   'logits': array([-0.02366066], dtype=float32),
#   'probabilities': array([0.50591487, 0.49408507], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7309466], dtype=float32),
#   'logits': array([0.9994308], dtype=float32),
#   'probabilities': array([0.26905334, 0.7309466 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38719282], dtype=float32),
#   'logits': array([-0.45912755], dtype=float32),
#   'probabilities': array([0.6128072 , 0.38719282], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21925704], dtype=float32),
#   'logits': array([-1.2700012], dtype=float32),
#   'probabilities': array([0.78074294, 0.21925704], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29687205], dtype=float32),
#   'logits': array([-0.8622377], dtype=float32),
#   'probabilities': array([0.703128  , 0.29687205], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5547111], dtype=float32),
#   'logits': array([0.2197243], dtype=float32),
#   'probabilities': array([0.44528884, 0.5547111 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19445258], dtype=float32),
#   'logits': array([-1.4213338], dtype=float32),
#   'probabilities': array([0.8055474 , 0.19445257], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61592513], dtype=float32),
#   'logits': array([0.47228777], dtype=float32),
#   'probabilities': array([0.3840749 , 0.61592513], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3966968], dtype=float32),
#   'logits': array([-0.4192477], dtype=float32),
#   'probabilities': array([0.60330325, 0.39669678], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39002293], dtype=float32),
#   'logits': array([-0.4472158], dtype=float32),
#   'probabilities': array([0.60997707, 0.39002293], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1270643], dtype=float32),
#   'logits': array([-1.9271686], dtype=float32),
#   'probabilities': array([0.87293565, 0.1270643 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15976804], dtype=float32),
#   'logits': array([-1.6599549], dtype=float32),
#   'probabilities': array([0.84023196, 0.15976804], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.155937], dtype=float32),
#   'logits': array([-1.6887751], dtype=float32),
#   'probabilities': array([0.844063  , 0.15593699], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41146427], dtype=float32),
#   'logits': array([-0.3579154], dtype=float32),
#   'probabilities': array([0.5885357 , 0.41146427], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12254956], dtype=float32),
#   'logits': array([-1.9685049], dtype=float32),
#   'probabilities': array([0.87745047, 0.12254957], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.73027694], dtype=float32),
#   'logits': array([0.99602807], dtype=float32),
#   'probabilities': array([0.26972306, 0.73027694], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16268645], dtype=float32),
#   'logits': array([-1.6383739], dtype=float32),
#   'probabilities': array([0.83731353, 0.16268645], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48320895], dtype=float32),
#   'logits': array([-0.06718957], dtype=float32),
#   'probabilities': array([0.51679105, 0.4832089 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12884226], dtype=float32),
#   'logits': array([-1.9112341], dtype=float32),
#   'probabilities': array([0.87115777, 0.12884228], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6542692], dtype=float32),
#   'logits': array([0.6378586], dtype=float32),
#   'probabilities': array([0.34573075, 0.6542692 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27549198], dtype=float32),
#   'logits': array([-0.9669343], dtype=float32),
#   'probabilities': array([0.724508  , 0.27549195], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16708152], dtype=float32),
#   'logits': array([-1.6064539], dtype=float32),
#   'probabilities': array([0.8329185 , 0.16708153], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29925144], dtype=float32),
#   'logits': array([-0.850865], dtype=float32),
#   'probabilities': array([0.70074856, 0.29925144], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2862368], dtype=float32),
#   'logits': array([-0.9137318], dtype=float32),
#   'probabilities': array([0.71376324, 0.28623682], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14905861], dtype=float32),
#   'logits': array([-1.7420037], dtype=float32),
#   'probabilities': array([0.85094136, 0.14905861], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.66531837], dtype=float32),
#   'logits': array([0.6870861], dtype=float32),
#   'probabilities': array([0.3346816, 0.6653184], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16762468], dtype=float32),
#   'logits': array([-1.602556], dtype=float32),
#   'probabilities': array([0.83237535, 0.1676247 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15534], dtype=float32),
#   'logits': array([-1.6933179], dtype=float32),
#   'probabilities': array([0.84466   , 0.15533999], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24470592], dtype=float32),
#   'logits': array([-1.12705], dtype=float32),
#   'probabilities': array([0.7552941 , 0.24470592], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43023497], dtype=float32),
#   'logits': array([-0.28089243], dtype=float32),
#   'probabilities': array([0.56976503, 0.43023503], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23283285], dtype=float32),
#   'logits': array([-1.192384], dtype=float32),
#   'probabilities': array([0.7671672 , 0.23283285], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10041648], dtype=float32),
#   'logits': array([-2.1926055], dtype=float32),
#   'probabilities': array([0.8995835 , 0.10041649], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82274455], dtype=float32),
#   'logits': array([1.5350538], dtype=float32),
#   'probabilities': array([0.17725545, 0.82274455], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6385203], dtype=float32),
#   'logits': array([0.5689478], dtype=float32),
#   'probabilities': array([0.36147964, 0.6385203 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.475884], dtype=float32),
#   'logits': array([-0.09653902], dtype=float32),
#   'probabilities': array([0.52411604, 0.475884  ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.67929107], dtype=float32),
#   'logits': array([0.7505157], dtype=float32),
#   'probabilities': array([0.32070896, 0.67929107], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10920867], dtype=float32),
#   'logits': array([-2.0988498], dtype=float32),
#   'probabilities': array([0.89079136, 0.10920867], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11897758], dtype=float32),
#   'logits': array([-2.0021482], dtype=float32),
#   'probabilities': array([0.8810225 , 0.11897758], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18408309], dtype=float32),
#   'logits': array([-1.4889253], dtype=float32),
#   'probabilities': array([0.8159169 , 0.18408307], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28679729], dtype=float32),
#   'logits': array([-0.91099], dtype=float32),
#   'probabilities': array([0.7132027, 0.2867973], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3189038], dtype=float32),
#   'logits': array([-0.7588141], dtype=float32),
#   'probabilities': array([0.6810962, 0.3189038], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5025374], dtype=float32),
#   'logits': array([0.01014996], dtype=float32),
#   'probabilities': array([0.49746254, 0.5025375 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53235793], dtype=float32),
#   'logits': array([0.1296128], dtype=float32),
#   'probabilities': array([0.4676421 , 0.53235793], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37117916], dtype=float32),
#   'logits': array([-0.5271616], dtype=float32),
#   'probabilities': array([0.62882084, 0.37117913], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3223081], dtype=float32),
#   'logits': array([-0.7431849], dtype=float32),
#   'probabilities': array([0.67769194, 0.3223081 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33013836], dtype=float32),
#   'logits': array([-0.7075593], dtype=float32),
#   'probabilities': array([0.6698616 , 0.33013836], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16217853], dtype=float32),
#   'logits': array([-1.6421072], dtype=float32),
#   'probabilities': array([0.8378215 , 0.16217855], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5774944], dtype=float32),
#   'logits': array([0.31249583], dtype=float32),
#   'probabilities': array([0.42250565, 0.5774944 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10766444], dtype=float32),
#   'logits': array([-2.1148229], dtype=float32),
#   'probabilities': array([0.89233553, 0.10766444], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21916342], dtype=float32),
#   'logits': array([-1.2705481], dtype=float32),
#   'probabilities': array([0.7808365 , 0.21916343], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5046594], dtype=float32),
#   'logits': array([0.01863813], dtype=float32),
#   'probabilities': array([0.49534062, 0.5046594 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28684887], dtype=float32),
#   'logits': array([-0.9107378], dtype=float32),
#   'probabilities': array([0.7131511 , 0.28684887], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17017029], dtype=float32),
#   'logits': array([-1.5844209], dtype=float32),
#   'probabilities': array([0.82982975, 0.17017028], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23418035], dtype=float32),
#   'logits': array([-1.1848552], dtype=float32),
#   'probabilities': array([0.76581967, 0.23418035], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21458244], dtype=float32),
#   'logits': array([-1.2975215], dtype=float32),
#   'probabilities': array([0.78541756, 0.21458244], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11366715], dtype=float32),
#   'logits': array([-2.0538182], dtype=float32),
#   'probabilities': array([0.88633287, 0.11366714], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18381694], dtype=float32),
#   'logits': array([-1.4906983], dtype=float32),
#   'probabilities': array([0.8161831 , 0.18381694], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52482396], dtype=float32),
#   'logits': array([0.09937751], dtype=float32),
#   'probabilities': array([0.47517607, 0.52482396], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.69393337], dtype=float32),
#   'logits': array([0.8185731], dtype=float32),
#   'probabilities': array([0.30606663, 0.69393337], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5971352], dtype=float32),
#   'logits': array([0.3935424], dtype=float32),
#   'probabilities': array([0.40286484, 0.5971352 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6532007], dtype=float32),
#   'logits': array([0.63313794], dtype=float32),
#   'probabilities': array([0.3467994, 0.6532007], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4085359], dtype=float32),
#   'logits': array([-0.37002134], dtype=float32),
#   'probabilities': array([0.5914641 , 0.40853584], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2794009], dtype=float32),
#   'logits': array([-0.9474354], dtype=float32),
#   'probabilities': array([0.7205991, 0.2794009], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4843069], dtype=float32),
#   'logits': array([-0.06279302], dtype=float32),
#   'probabilities': array([0.5156931 , 0.48430693], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16508105], dtype=float32),
#   'logits': array([-1.620898], dtype=float32),
#   'probabilities': array([0.834919  , 0.16508107], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.133496], dtype=float32),
#   'logits': array([-1.8703952], dtype=float32),
#   'probabilities': array([0.866504, 0.133496], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15410453], dtype=float32),
#   'logits': array([-1.7027647], dtype=float32),
#   'probabilities': array([0.8458954 , 0.15410452], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46769702], dtype=float32),
#   'logits': array([-0.12939227], dtype=float32),
#   'probabilities': array([0.53230304, 0.467697  ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.04597268], dtype=float32),
#   'logits': array([-3.032645], dtype=float32),
#   'probabilities': array([0.95402735, 0.04597268], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22250591], dtype=float32),
#   'logits': array([-1.2511224], dtype=float32),
#   'probabilities': array([0.77749413, 0.22250593], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14850473], dtype=float32),
#   'logits': array([-1.7463771], dtype=float32),
#   'probabilities': array([0.85149527, 0.14850473], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24772139], dtype=float32),
#   'logits': array([-1.110802], dtype=float32),
#   'probabilities': array([0.7522786 , 0.24772139], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22057949], dtype=float32),
#   'logits': array([-1.2622925], dtype=float32),
#   'probabilities': array([0.7794205, 0.2205795], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24250355], dtype=float32),
#   'logits': array([-1.1390026], dtype=float32),
#   'probabilities': array([0.7574964 , 0.24250352], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.74315965], dtype=float32),
#   'logits': array([1.0624563], dtype=float32),
#   'probabilities': array([0.25684035, 0.74315965], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14313857], dtype=float32),
#   'logits': array([-1.789463], dtype=float32),
#   'probabilities': array([0.8568614 , 0.14313856], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10199506], dtype=float32),
#   'logits': array([-2.1752512], dtype=float32),
#   'probabilities': array([0.89800495, 0.10199506], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.536875], dtype=float32),
#   'logits': array([0.14776838], dtype=float32),
#   'probabilities': array([0.46312496, 0.536875  ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45402503], dtype=float32),
#   'logits': array([-0.18442094], dtype=float32),
#   'probabilities': array([0.545975, 0.454025], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8166864], dtype=float32),
#   'logits': array([1.4940566], dtype=float32),
#   'probabilities': array([0.18331364, 0.8166864 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61836386], dtype=float32),
#   'logits': array([0.4826094], dtype=float32),
#   'probabilities': array([0.38163617, 0.61836386], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10184363], dtype=float32),
#   'logits': array([-2.1769056], dtype=float32),
#   'probabilities': array([0.89815634, 0.10184362], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6067447], dtype=float32),
#   'logits': array([0.43364906], dtype=float32),
#   'probabilities': array([0.3932553, 0.6067447], dtype=float32)}]

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10], feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\devan\AppData\Local\Temp\tmpm8k5mhu4
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\devan\\AppData\\Local\\Temp\\tmpm8k5mhu4', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000220B33AE908>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn= input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-f2ee1f7c6650> in <module>()
# ----> 1 dnn_model.train(input_fn= input_func, steps=1000)
#
# c:\users\devan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\estimator\estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     350
#     351     saving_listeners = _check_listeners_type(saving_listeners)
# --> 352     loss = self._train_model(input_fn, hooks, saving_listeners)
#     353     logging.info('Loss for final step: %s.', loss)
#     354     return self
#
# c:\users\devan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\estimator\estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#     810       worker_hooks.extend(input_hooks)
#     811       estimator_spec = self._call_model_fn(
# --> 812           features, labels, model_fn_lib.ModeKeys.TRAIN, self.config)
#     813
#     814       if self._warm_start_settings:
#
# c:\users\devan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\estimator\estimator.py in _call_model_fn(self, features, labels, mode, config)
#     791
#     792     logging.info('Calling model_fn.')
# --> 793     model_fn_results = self._model_fn(features=features, **kwargs)
#     794     logging.info('Done calling model_fn.')
#     795
#
# c:\users\devan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\estimator\canned\dnn.py in _model_fn(features, labels, mode, config)
#     352           dropout=dropout,
#     353           input_layer_partitioner=input_layer_partitioner,
# --> 354           config=config)
#     355
#     356     super(DNNClassifier, self).__init__(
#
# c:\users\devan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\estimator\canned\dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config)
#     183         dropout=dropout,
#     184         input_layer_partitioner=input_layer_partitioner)
# --> 185     logits = logit_fn(features=features, mode=mode)
#     186
#     187     def _train_op_fn(loss):
#
# c:\users\devan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\estimator\canned\dnn.py in dnn_logit_fn(features, mode)
#      89         partitioner=input_layer_partitioner):
#      90       net = feature_column_lib.input_layer(
# ---> 91           features=features, feature_columns=feature_columns)
#      92     for layer_id, num_hidden_units in enumerate(hidden_units):
#      93       with variable_scope.variable_scope(
#
# c:\users\devan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\feature_column\feature_column.py in input_layer(features, feature_columns, weight_collections, trainable, cols_to_vars)
#     271   """
#     272   return _internal_input_layer(features, feature_columns, weight_collections,
# --> 273                                trainable, cols_to_vars)
#     274
#     275
#
# c:\users\devan\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\feature_column\feature_column.py in _internal_input_layer(features, feature_columns, weight_collections, trainable, cols_to_vars, scope)
#     175           'Items of feature_columns must be a _DenseColumn. '
#     176           'You can wrap a categorical column with an '
# --> 177           'embedding_column or indicator_column. Given: {}'.format(column))
#     178   weight_collections = list(weight_collections or [])
#     179   if ops.GraphKeys.GLOBAL_VARIABLES not in weight_collections:
#
# ValueError: Items of feature_columns must be a _DenseColumn. You can wrap a categorical column with an embedding_column or indicator_column. Given: _VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
#if error
embeded_group_col = tf.feature_column.embedding_column(assigned_group,dimension=4)
feat_cols = [num_preg,plasma_gluc,dias_press,tricep,insulin,bmi,diabetes_pedigree,embeded_group_col,age_bucket]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(X_train,y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,20,20,20,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\devan\AppData\Local\Temp\tmpiwnuzxfz
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\devan\\AppData\\Local\\Temp\\tmpiwnuzxfz', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000220B352CFD0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\devan\AppData\Local\Temp\tmpiwnuzxfz\model.ckpt.
# INFO:tensorflow:loss = 6.454049, step = 1
# INFO:tensorflow:global_step/sec: 153.555
# INFO:tensorflow:loss = 6.250923, step = 101 (0.653 sec)
# INFO:tensorflow:global_step/sec: 174.208
# INFO:tensorflow:loss = 5.283634, step = 201 (0.575 sec)
# INFO:tensorflow:global_step/sec: 179.701
# INFO:tensorflow:loss = 6.8587275, step = 301 (0.556 sec)
# INFO:tensorflow:global_step/sec: 168.755
# INFO:tensorflow:loss = 4.158627, step = 401 (0.592 sec)
# INFO:tensorflow:global_step/sec: 176.676
# INFO:tensorflow:loss = 5.088107, step = 501 (0.567 sec)
# INFO:tensorflow:global_step/sec: 174.972
# INFO:tensorflow:loss = 3.8141737, step = 601 (0.572 sec)
# INFO:tensorflow:global_step/sec: 167.761
# INFO:tensorflow:loss = 4.5994596, step = 701 (0.596 sec)
# INFO:tensorflow:global_step/sec: 173.3
# INFO:tensorflow:loss = 3.1169083, step = 801 (0.577 sec)
# INFO:tensorflow:global_step/sec: 175.279
# INFO:tensorflow:loss = 4.8901954, step = 901 (0.573 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\devan\AppData\Local\Temp\tmpiwnuzxfz\model.ckpt.
# INFO:tensorflow:Loss for final step: 2.5477803.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,y=y_test,batch_size=10,num_epochs=1,shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-19-17:01:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\devan\AppData\Local\Temp\tmpiwnuzxfz\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-19-17:01:45
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7056277, accuracy_baseline = 0.64935064, auc = 0.8147737, auc_precision_recall = 0.6913769, average_loss = 0.50838935, global_step = 1000, label/mean = 0.35064936, loss = 4.893247, prediction/mean = 0.33646584
# {'accuracy': 0.7056277,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.8147737,
#  'auc_precision_recall': 0.6913769,
#  'average_loss': 0.50838935,
#  'global_step': 1000,
#  'label/mean': 0.35064936,
#  'loss': 4.893247,
#  'prediction/mean': 0.33646584}
